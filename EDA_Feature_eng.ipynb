# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("./Algerian_forest_fires_cleaned_dataset.csv")

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
# df = df_0.drop(columns=["day", "month", "year"], axis=1)

# %%
df["Classes"].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1    2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2    3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3    4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4    5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# 5    6      6  2012           31  67  14   0.0  82.6   5.8  22.2  3.1   7.0
# 6    7      6  2012           33  54  13   0.0  88.2   9.9  30.5  6.4  10.9
# 7    8      6  2012           30  73  15   0.0  86.6  12.1  38.3  5.6  13.5
# 8    9      6  2012           25  88  13   0.2  52.9   7.9  38.8  0.4  10.5
# 9   10      6  2012           28  79  12   0.0  73.2   9.5  46.3  1.3  12.6
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# ...

# %%
df["Classes"] = np.where(df["Classes"].str.contains("not fire"),0,1)

# %%
df.head(10)
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1    2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2    3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3    4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4    5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# 5    6      6  2012           31  67  14   0.0  82.6   5.8  22.2  3.1   7.0
# 6    7      6  2012           33  54  13   0.0  88.2   9.9  30.5  6.4  10.9
# 7    8      6  2012           30  73  15   0.0  86.6  12.1  38.3  5.6  13.5
# 8    9      6  2012           25  88  13   0.2  52.9   7.9  38.8  0.4  10.5
# 9   10      6  2012           28  79  12   0.0  73.2   9.5  46.3  1.3  12.6
#
#    FWI  Classes  Region
# 0  0.5        0       0
# 1  0.4        0       0
# 2  0.1        0       0
# 3  0.0        0       0
# ...

# %%
df["Classes"].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.figure(figsize=(20, 20))
num_features = len(df.columns)
rows = (num_features // 3) + (num_features % 3 > 0)  # Calculate required rows

for i, column in enumerate(df.columns):
    plt.subplot(rows, 3, i + 1)  # Create a flexible grid
    sns.kdeplot(data=df[column], fill=True, color="blue")
    plt.title(f"Density Plot for {column}")
    plt.xlabel(column)
    plt.ylabel("Density")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\chandula\AppData\Local\Temp\ipykernel_11656\3241426788.py:12: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=df[column], fill=True, color="blue")

# %%
percentage = df["Classes"].value_counts(normalize=True)*100

# %%
classlabels = ["Fire", "Not Fire"]
plt.figure(figsize=(12, 7))
plt.pie(percentage, labels=classlabels, autopct='%1.1f%%')
plt.title("pie chat of classes")
# Out:
# Text(0.5, 1.0, 'pie chat of classes')

# %%
df.corr()
# Out:
#                   day     month  year  Temperature        RH        Ws  \
# day          1.000000 -0.000369   NaN     0.097227 -0.076034  0.047812
# month       -0.000369  1.000000   NaN    -0.056781 -0.041252 -0.039880
# year              NaN       NaN   NaN          NaN       NaN       NaN
# Temperature  0.097227 -0.056781   NaN     1.000000 -0.651400 -0.284510
# RH          -0.076034 -0.041252   NaN    -0.651400  1.000000  0.244048
# Ws           0.047812 -0.039880   NaN    -0.284510  0.244048  1.000000
# Rain        -0.112523  0.034822   NaN    -0.326492  0.222356  0.171506
# FFMC         0.224956  0.017030   NaN     0.676568 -0.644873 -0.166548
# DMC          0.491514  0.067943   NaN     0.485687 -0.408519 -0.000721
# DC           0.527952  0.126511   NaN     0.376284 -0.226941  0.079135
# ISI          0.180543  0.065608   NaN     0.603871 -0.686667  0.008532
# BUI          0.517117  0.085073   NaN     0.459789 -0.353841  0.031438
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.boxplot(df["FWI"])
# Out:
# <Axes: ylabel='FWI'>

# %%
dftemp = df.loc[df["Region"]==1]
plt.subplots(figsize=(13, 16))
sns.set_style("whitegrid")
sns.countplot(x="month", hue="Classes", data=df)
plt.ylabel("Number of fires", weight="bold")
plt.xlabel("Months", weight="bold")
plt.title("fire analysis of sidi-bel region")
# Out:
# Text(0.5, 1.0, 'fire analysis of sidi-bel region')

# %%
dftemp = df.loc[df["Region"]==0]
plt.subplots(figsize=(13, 16))
sns.set_style("whitegrid")
sns.countplot(x="month", hue="Classes", data=df)
plt.ylabel("Number of fires", weight="bold")
plt.xlabel("Months", weight="bold")
plt.title("fire analysis of brijai region")
# Out:
# Text(0.5, 1.0, 'fire analysis of brijai region')
